# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/UPGRAD/Python upgrad lecture practice/Machine learning/laptop_price.csv", encoding = "latin")
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.drop(columns = ["laptop_ID"], inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1286  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1287      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1288    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1289    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1290    Dell                              Inspiron 3567            Notebook
# 1291    Acer                             Aspire ES1-531            Notebook
# 1292    Dell                              Inspiron 3552            Notebook
# 1293  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1294      HP                        Pavilion 15-AW003nv            Notebook
# 1295    Dell                              Inspiron 3567            Notebook
# 1296      HP                           Stream 11-Y000na             Netbook
# 1297    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1298  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1301      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Inches                            ScreenResolution  \
# 1275    13.3                 IPS Panel Full HD 1920x1080
# 1276    15.6                                    1366x768
# 1277    15.6                                    1366x768
# 1278    15.6                                    1366x768
# 1279    15.6                 IPS Panel Full HD 1920x1080
# 1280    15.6                           Full HD 1920x1080
# 1281    15.6                                    1366x768
# 1282    11.6                                    1366x768
# 1283    15.6                                    1366x768
# 1284    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1285    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286    14.0                                    1366x768
# 1287    15.6                                    1366x768
# 1288    15.6                                    1366x768
# 1289    13.3                 IPS Panel Full HD 1920x1080
# 1290    15.6                                    1366x768
# 1291    15.6                                    1366x768
# 1292    15.6                                    1366x768
# 1293    15.6                 IPS Panel Full HD 1920x1080
# 1294    15.6                           Full HD 1920x1080
# 1295    15.6                                    1366x768
# 1296    11.6                                    1366x768
# 1297    15.6                                    1366x768
# 1298    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300    14.0                                    1366x768
# 1301    15.6                                    1366x768
# 1302    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1275              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                           Gpu       OpSys  Weight  Price_euros
# 1275    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1276    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1277    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1278        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1279  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1280       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1281       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1282    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1283      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1284    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1285    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1286        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1287       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1288        Intel HD Graphics  Windows 10   2.2kg       369.00
# 1289    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1290    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1291    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1292        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1293  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1294       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1295       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1296    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1297      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1298    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302        Intel HD Graphics  Windows 10   2.2kg       369.00

# %%
df.drop_duplicates(inplace = True, ignore_index = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   Product           1275 non-null   object
#  2   TypeName          1275 non-null   object
#  3   Inches            1275 non-null   float64
#  4   ScreenResolution  1275 non-null   object
#  5   Cpu               1275 non-null   object
#  6   Ram               1275 non-null   object
#  7   Memory            1275 non-null   object
#  8   Gpu               1275 non-null   object
#  9   OpSys             1275 non-null   object
#  10  Weight            1275 non-null   object
#  11  Price_euros       1275 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 119.7+ KB

# %%
df.describe()
# Out:
#             Inches  Price_euros
# count  1275.000000  1275.000000
# mean     15.022902  1134.969059
# std       1.429470   700.752504
# min      10.100000   174.000000
# 25%      14.000000   609.000000
# 50%      15.600000   989.000000
# 75%      15.600000  1496.500000
# max      18.400000  6099.000000

# %%
df['Price'] = round(df['Price_euros']*93.25184).astype('int')

# %%
df.drop(columns= ['Price_euros'], inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  124929
# 1        Intel HD Graphics 6000  macOS  1.34kg   83828
# 2         Intel HD Graphics 620  No OS  1.86kg   53620
# 3            AMD Radeon Pro 455  macOS  1.83kg  236622
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg  168189

# %%
df['Price'].describe()
# Out:
# count      1275.000000
# mean     105837.960000
# std       65346.456907
# min       16226.000000
# 25%       56790.000000
# 50%       92226.000000
# 75%      139551.500000
# max      568743.000000
# Name: Price, dtype: float64

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Price'].skew()
# Out:
# 1.5111472496205085

# %%
df['Price'].kurtosis()
# Out:
# 4.3408196587754455

# %%
# The data is right skewed
# For a normally distributed data, ideally skew = 0, kurtosis = 3

# Typically, for right skewed data, log operation can be performed
# Or we could eliminate the data points which are outliers

# %%
sns.kdeplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
# EDA and Feature Engineering

# %%
# Company

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
9+7+7+6+4+4+3+3+3+3+2
# Out:
# 51

# %%
51/1275
# Out:
# 0.04

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x = df['Company'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
print(df.groupby('Company').Company.transform('count'))
# Out:
# 0        21
# 1        21
# 2       268
# 3        21
# 4        21
#        ...
# 1270    289
# 1271    289
# 1272    289
# 1273    268
# 1274    152
# Name: Company, Length: 1275, dtype: int64

# %%
df=df[df.groupby('Company').Company.transform('count')>20]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1219  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1220  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1221  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1222      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1223    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1219   IPS Panel Full HD / Touchscreen 1920x1080
# 1220  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1221                                    1366x768
# 1222                                    1366x768
# 1223                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1219            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1220            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1221  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1222            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1223  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  124929
# 1           Intel HD Graphics 6000       macOS  1.34kg   83828
# 2            Intel HD Graphics 620       No OS  1.86kg   53620
# 3               AMD Radeon Pro 455       macOS  1.83kg  236622
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  168189
# ...                            ...         ...     ...     ...
# 1219         Intel HD Graphics 520  Windows 10   1.8kg   59495
# 1220         Intel HD Graphics 520  Windows 10   1.3kg  139785
# 1221             Intel HD Graphics  Windows 10   1.5kg   21355
# 1222            AMD Radeon R5 M330  Windows 10  2.19kg   71244
# 1223             Intel HD Graphics  Windows 10   2.2kg   34410
#
# [1224 rows x 12 columns]

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'],errorbar=None)
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
df.groupby('Company')['Price'].mean().sort_values(ascending = False)
# Out:
# Company
# MSI        161223.888889
# Apple      145864.428571
# Toshiba    118225.854167
# Dell       111829.955326
# Asus       104799.184211
# Lenovo     102004.674740
# HP         100741.328358
# Acer        59071.762376
# Name: Price, dtype: float64

# %%
sns.barplot(x=df['Company'],y=df['Price'],errorbar=None, order = ['MSI', 'Apple', 'Toshiba', 'Dell', 'Asus', 'Lenovo', 'HP', 'Acer'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
df.groupby('Company')['Price'].mean().index
# Out:
# Index(['Acer', 'Apple', 'Asus', 'Dell', 'HP', 'Lenovo', 'MSI', 'Toshiba'], dtype='object', name='Company')

# %%
df.groupby('Company')['Price'].mean().sort_values(ascending=False)
# Out:
# Company
# MSI        161223.888889
# Apple      145864.428571
# Toshiba    118225.854167
# Dell       111829.955326
# Asus       104799.184211
# Lenovo     102004.674740
# HP         100741.328358
# Acer        59071.762376
# Name: Price, dtype: float64

# %%
company_sorted_price=df.groupby('Company')['Price'].mean().sort_values(ascending=False).index
company_sorted_price
# Out:
# Index(['MSI', 'Apple', 'Toshiba', 'Dell', 'Asus', 'Lenovo', 'HP', 'Acer'], dtype='object', name='Company')

# %%
sns.barplot(x=df['Company'],y=df['Price'],errorbar=None,order=company_sorted_price)
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
# Product
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# <ipython-input-230-4bcf6fa0a033>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  124929
# 1        Intel HD Graphics 6000  macOS  1.34kg   83828
# 2         Intel HD Graphics 620  No OS  1.86kg   53620
# 3            AMD Radeon Pro 455  macOS  1.83kg  236622
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg  168189

# %%
# TypeName

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
df.groupby('TypeName')['Price'].mean().sort_values(ascending=False)
# Out:
# TypeName
# Workstation           212647.689655
# Gaming                155888.190000
# Ultrabook             144559.666667
# 2 in 1 Convertible    121177.973684
# Notebook               74219.122093
# Netbook                64508.318182
# Name: Price, dtype: float64

# %%
a=df.groupby('TypeName')['Price'].mean().sort_values(ascending=False).index
sns.barplot(x=df['TypeName'],y=df['Price'],errorbar=None,order=a,palette='summer')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-236-e46b1e8e3108>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['TypeName'],y=df['Price'],errorbar=None,order=a,palette='summer')

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
sns.displot(x=df['Inches'],kde=True)

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
# ScreenResolution

# %%
print(df['ScreenResolution'].value_counts())
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
a = 'IPS Panel Full HD / Touchscreen 1920x1080'
a
# Out:
# 'IPS Panel Full HD / Touchscreen 1920x1080'

# %%
a.split()
# Out:
# ['IPS', 'Panel', 'Full', 'HD', '/', 'Touchscreen', '1920x1080']

# %%
a.split()[-1]
# Out:
# '1920x1080'

# %%
a.split()[-1].split('x')
# Out:
# ['1920', '1080']

# %%
int(a.split()[-1].split('x')[0])
# Out:
# 1920

# %%
(lambda a:int(a.split()[-1].split('x')[0]))("IPS Panel Full HD / Touchscreen 1920x1080")
# Out:
# 1920

# %%
df.loc[:,'X_res'] = df['ScreenResolution'].apply(lambda a:int(a.split()[-1].split('x')[0]))
df.loc[:,'Y_res']= df['ScreenResolution'].apply(lambda a:int(a.split()[-1].split('x')[1]))
# Out:
# <ipython-input-249-3f38a2ca3182>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'X_res'] = df['ScreenResolution'].apply(lambda a:int(a.split()[-1].split('x')[0]))
# <ipython-input-249-3f38a2ca3182>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Y_res']= df['ScreenResolution'].apply(lambda a:int(a.split()[-1].split('x')[1]))

# %%
df.loc[:, "IPS"]= df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0)
df.loc[:,"Touchscreen"]= df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0)
# Out:
# <ipython-input-250-e575e63456f7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, "IPS"]= df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0)
# <ipython-input-250-e575e63456f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,"Touchscreen"]= df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches    ScreenResolution  \
# 848       HP  Notebook    14.0   Full HD 1920x1080
# 591     Dell  Notebook    15.6   Full HD 1920x1080
# 1041      HP  Notebook    13.3  Quad HD+ 3200x1800
# 600   Lenovo  Notebook    15.6   Full HD 1920x1080
# 862       HP   Netbook    12.5   Full HD 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 848             Intel Core i5 7200U 2.5GHz  4GB           128GB SSD
# 591             Intel Core i5 7200U 2.5GHz  4GB           128GB SSD
# 1041  Intel Pentium Dual Core 4405Y 1.5GHz  4GB  32GB Flash Storage
# 600             Intel Core i5 7200U 2.5GHz  4GB           128GB SSD
# 862             Intel Core i7 7500U 2.7GHz  8GB           512GB SSD
#
#                         Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 848   Intel HD Graphics 620  Windows 10  1.95kg  117964   1920   1080    0
# 591      AMD Radeon R5 M420       Linux  2.18kg   53060   1920   1080    0
# 1041  Intel HD Graphics 515   Chrome OS  1.29kg   57350   3200   1800    0
# 600   Intel HD Graphics 620       No OS   2.2kg   43642   1920   1080    0
# 862   Intel HD Graphics 620  Windows 10  1.26kg  138292   1920   1080    0
#
#       Touchscreen
# 848             0
# 591             0
# 1041            0
# 600             0
# 862             0

# %%
df.drop(columns = ['ScreenResolution'], inplace = True)
# Out:
# <ipython-input-252-4d0de2621c4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['ScreenResolution'], inplace = True)

# %%
df.sample()
# Out:
#     Company TypeName  Inches                          Cpu   Ram   Memory  \
# 452      HP   Gaming    17.3  Intel Core i7 7700HQ 2.8GHz  12GB  1TB HDD
#
#                          Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 452  Nvidia GeForce GTX 1060  Windows 10  3.78kg  158435   1920   1080    1
#
#      Touchscreen
# 452            0

# %%
# RAM Columns

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype("int")
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')
# Out:
# <ipython-input-255-bbeb8d629999>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype("int")
# <ipython-input-255-bbeb8d629999>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
print(df.dtypes)
# Out:
# Company         object
# TypeName        object
# Inches         float64
# Cpu             object
# Ram              int64
# Memory          object
# Gpu             object
# OpSys           object
# Weight         float64
# Price            int64
# X_res            int64
# Y_res            int64
# IPS              int64
# Touchscreen      int64
# dtype: object

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    885
# 1    339
# Name: count, dtype: int64

# %%
df['IPS'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x = df['IPS'], y = df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x = df['Touchscreen'], y = df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     595
# 4     351
# 16    186
# 6      34
# 12     25
# 32     15
# 2      14
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x = df['Ram'], y = df['Price'], errorbar = None, palette = 'summer', hue =df['Ram'], legend=False)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df['Weight'].describe()
# Out:
# count    1224.000000
# mean        2.063204
# std         0.663863
# min         0.690000
# 25%         1.597500
# 50%         2.060000
# 75%         2.320000
# max         4.700000
# Name: Weight, dtype: float64

# %%
sns.displot(x = df['Weight'], kde=True)

# %%
plt.figure(figsize = (14, 6))
sns.scatterplot(x = df['Weight'], y = df['Price'], hue = df['TypeName'], palette = 'husl')
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 111, dtype: int64

# %%
df['Cpu_Speed'] = df['Cpu'].apply(lambda x:x.split()[-1].replace('GHz', "")).astype('float')
# Out:
# <ipython-input-270-d295aa6b5cc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu_Speed'] = df['Cpu'].apply(lambda x:x.split()[-1].replace('GHz', "")).astype('float')

# %%
a = "Intel Core i5 8250U 1.6GHz"
a
# Out:
# 'Intel Core i5 8250U 1.6GHz'

# %%
" ".join(a.split()[:-1])
# Out:
# 'Intel Core i5 8250U'

# %%
df['Cpu'] = df['Cpu'].apply(lambda a:" ".join(a.split()[:-1]))
# Out:
# <ipython-input-273-44815bf5406b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu'] = df['Cpu'].apply(lambda a:" ".join(a.split()[:-1]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U     186
# Intel Core i7 7700HQ    143
# Intel Core i7 7500U     124
# Intel Core i3 6006U      81
# Intel Core i7 8550U      71
#                        ...
# Intel Core M 7Y30         1
# Intel Core i5 6440HQ      1
# Intel Core i5 7500U       1
# AMD Ryzen 1600            1
# AMD A9-Series 9410        1
# Name: count, Length: 87, dtype: int64

# %%
df.sample()
# Out:
#     Company            TypeName  Inches                  Cpu  Ram     Memory  \
# 676    Acer  2 in 1 Convertible    13.3  Intel Core i5 8250U    8  256GB SSD
#
#                         Gpu       OpSys  Weight  Price  X_res  Y_res  IPS  \
# 676  Intel UHD Graphics 620  Windows 10     1.6  93159   1920   1080    1
#
#      Touchscreen  Cpu_Speed
# 676            1        1.6

# %%
df["Cpu"] = df["Cpu"].apply(lambda a:" ".join(a.split()[:3]))
# Out:
# <ipython-input-276-69f27521222e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cpu"] = df["Cpu"].apply(lambda a:" ".join(a.split()[:3]))

# %%
df.sample()
# Out:
#      Company            TypeName  Inches            Cpu  Ram     Memory  \
# 1192    Dell  2 in 1 Convertible    17.3  Intel Core i7   16  512GB SSD
#
#                        Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 1192  Nvidia GeForce 940MX  Windows 10    2.77  167760   1920   1080    0
#
#       Touchscreen  Cpu_Speed
# 1192            1        2.7

# %%
print(df["Cpu"].value_counts())
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom x5-Z8350           1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
def fetch_processor(text):
    if text == "Intel Core i7" or text == "Intel Core i7" or text == "Intel Core i5" or text == "Intel Core i3" or text == "Intel Core M":
        return text
    elif text.split()[0]=="Intel":
        return " ".join(text.split()[0:2])
    else:
        return "AMD "+str(text[4])+" - Series"

# %%
df['Cpu'] = df['Cpu'].apply(fetch_processor)
# Out:
# <ipython-input-280-807f446071e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu'] = df['Cpu'].apply(fetch_processor)

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i7     493
# Intel Core i5     411
# Intel Core i3     134
# Intel Celeron      71
# AMD A - Series     45
# Intel Pentium      30
# Intel Core M       16
# AMD E - Series      9
# Intel Atom          5
# AMD R - Series      4
# Intel Xeon          4
# AMD F - Series      2
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Cpu'>

# %%
a = df.groupby('Cpu')['Price'].mean().sort_values(ascending = False).index

# %%
sns.barplot(x = df['Cpu'], y = df['Price'], errorbar = None, order = a, palette = 'summer' )
plt.xticks(rotation = 90)
plt.show()
# Out:
# <ipython-input-284-17dd11ca12a0>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df['Cpu'], y = df['Price'], errorbar = None, order = a, palette = 'summer' )

# %%
df.head()
# Out:
#   Company   TypeName  Inches            Cpu  Ram               Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8            128GB SSD
# 1   Apple  Ultrabook    13.3  Intel Core i5    8  128GB Flash Storage
# 2      HP   Notebook    15.6  Intel Core i5    8            256GB SSD
# 3   Apple  Ultrabook    15.4  Intel Core i7   16            512GB SSD
# 4   Apple  Ultrabook    13.3  Intel Core i5    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  X_res  Y_res  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  124929   2560   1600    1
# 1        Intel HD Graphics 6000  macOS    1.34   83828   1440    900    0
# 2         Intel HD Graphics 620  No OS    1.86   53620   1920   1080    0
# 3            AMD Radeon Pro 455  macOS    1.83  236622   2880   1800    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  168189   2560   1600    1
#
#    Touchscreen  Cpu_Speed
# 0            0        2.3
# 1            0        1.8
# 2            0        2.5
# 3            0        2.7
# 4            0        3.1

# %%
sns.displot(df['Cpu_Speed'], kde = True)

# %%
plt.figure(figsize = (14,5))
sns.scatterplot(x = df['Cpu_Speed'], y = df['Price'], hue =df['Cpu'])
plt.xticks(np.arange(0.9, 3.7, 0.1))
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Inches            Cpu  Ram               Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8            128GB SSD
# 1   Apple  Ultrabook    13.3  Intel Core i5    8  128GB Flash Storage
# 2      HP   Notebook    15.6  Intel Core i5    8            256GB SSD
# 3   Apple  Ultrabook    15.4  Intel Core i7   16            512GB SSD
# 4   Apple  Ultrabook    13.3  Intel Core i5    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  X_res  Y_res  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  124929   2560   1600    1
# 1        Intel HD Graphics 6000  macOS    1.34   83828   1440    900    0
# 2         Intel HD Graphics 620  No OS    1.86   53620   1920   1080    0
# 3            AMD Radeon Pro 455  macOS    1.83  236622   2880   1800    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  168189   2560   1600    1
#
#    Touchscreen  Cpu_Speed
# 0            0        2.3
# 1            0        1.8
# 2            0        2.5
# 3            0        2.7
# 4            0        3.1

# %%
df.corr(numeric_only = True)
# Out:
#                Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches       1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram          0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight       0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# Price        0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# X_res       -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# Y_res       -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# IPS         -0.104090  0.223322  0.038753  0.289225  0.283969  0.294360
# Touchscreen -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# Cpu_Speed    0.296510  0.356482  0.313267  0.422535  0.187056  0.178539
#
#                   IPS  Touchscreen  Cpu_Speed
# Inches      -0.104090    -0.359497   0.296510
# Ram          0.223322     0.094037   0.356482
# Weight       0.038753    -0.291506   0.313267
# Price        0.289225     0.161443   0.422535
# X_res        0.283969     0.320954   0.187056
# Y_res        0.294360     0.317174   0.178539
# IPS          1.000000     0.154500   0.085098
# Touchscreen  0.154500     1.000000  -0.105203
# Cpu_Speed    0.085098    -0.105203   1.000000

# %%
sns.heatmap(df.corr(numeric_only = True), cmap = 'summer')
# Out:
# <Axes: >

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu_temp'] = df['Gpu'].apply(lambda x: " ".join(x.split()[:2]))
# Out:
# <ipython-input-292-dd960ace5de5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu_temp'] = df['Gpu'].apply(lambda x: " ".join(x.split()[:2]))

# %%
print(df['Gpu_temp'].value_counts())
# Out:
# Gpu_temp
# Intel HD          586
# Nvidia GeForce    353
# AMD Radeon        166
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# AMD R4              1
# Nvidia GTX          1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
def fetch_gpu(text):
    if text.split()[0]=="AMD":
        return "AMD GPU"
    elif text== "Intel HD" or text== "Nvidia GeForce" or text== "Intel UHD" or text== "Nvidia Quadro" or text== "Intel Iris":
        return text
    elif text== "Intel Graphics":
        return "Intel HD"
    elif text== "Nvidia GTX":
        return "Nvidia GeForce"

# %%
df['Gpu_temp'] = df['Gpu_temp'].apply(fetch_gpu)
# Out:
# <ipython-input-295-2fa5ff589f9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu_temp'] = df['Gpu_temp'].apply(fetch_gpu)

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu'] = df['Gpu_temp']
# Out:
# <ipython-input-297-9017328a8f09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu'] = df['Gpu_temp']

# %%
df.drop(columns = ['Gpu_temp'], inplace = True)
# Out:
# <ipython-input-298-85f032734856>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['Gpu_temp'], inplace = True)

# %%
df['Gpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
a = df.groupby('Gpu')['Price'].mean().sort_values(ascending = False)
print(a)
# Out:
# Gpu
# Nvidia Quadro     229260.516129
# Intel Iris        161213.000000
# Nvidia GeForce    128503.240113
# Intel UHD         112440.147059
# Intel HD           91801.521295
# AMD GPU            72002.098266
# Name: Price, dtype: float64

# %%
sns.barplot(x = df['Gpu'], y = df['Price'], errorbar = None, order = a.index, palette = 'winter')
plt.xticks(rotation = 90)
plt.show()
# Out:
# <ipython-input-301-5cb1d0fae3a3>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df['Gpu'], y = df['Price'], errorbar = None, order = a.index, palette = 'winter')

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: count, dtype: int64

# %%
def fetch_os(text):
    if text == "Windows 10" or text == "Windows 10 S":
        return "Windows 10"
    elif text == "macOS" or text == "Mac OS X":
        return "MacOS"
    elif text == "No OS" or text == "Windows 7":
        return text
    else:
        return "Linux/Chrome/Others"

# %%
df['OpSys'] = df['OpSys'].apply(fetch_os)
# Out:
# <ipython-input-304-f13495c0bb32>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OpSys'] = df['OpSys'].apply(fetch_os)

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10             1013
# Linux/Chrome/Others      82
# No OS                    63
# Windows 7                45
# MacOS                    21
# Name: count, dtype: int64

# %%
df[df['OpSys'] == "Windows 7"]
# Out:
#       Company            TypeName  Inches            Cpu  Ram        Memory  \
# 506    Lenovo            Notebook    14.0  Intel Core i5    8     256GB SSD
# 596    Lenovo            Notebook    14.0  Intel Core i5    8     256GB SSD
# 598        HP            Notebook    15.6  Intel Core i5    4     500GB HDD
# 677    Lenovo         Workstation    15.6  Intel Core i7   16     512GB SSD
# 717        HP         Workstation    17.3     Intel Xeon   16     256GB SSD
# 725        HP         Workstation    15.6  Intel Core i7    8     256GB SSD
# 741    Lenovo            Notebook    15.6  Intel Core i7   16     512GB SSD
# 804        HP           Ultrabook    14.0  Intel Core i7    8     512GB SSD
# 907   Toshiba            Notebook    13.3  Intel Core i5    8     256GB SSD
# 931    Lenovo            Notebook    14.0  Intel Core i5    4  508GB Hybrid
# 936   Toshiba            Notebook    13.3  Intel Core i5    4     128GB SSD
# 961        HP           Ultrabook    14.0  Intel Core i7    8     256GB SSD
# 971    Lenovo            Notebook    17.3  Intel Core i7   16     512GB SSD
# 987        HP            Notebook    14.0  Intel Core i5    8     256GB SSD
# 992      Dell            Notebook    15.6  Intel Core i5    8     256GB SSD
# 999        HP            Notebook    14.0  Intel Core i5    8     256GB SSD
# 1003   Lenovo            Notebook    14.0  Intel Core i7   16     256GB SSD
# 1025       HP           Ultrabook    12.5  Intel Core i5    8     256GB SSD
# 1032       HP            Notebook    15.6  Intel Core i5    4     500GB HDD
# 1038       HP            Notebook    14.0  Intel Core i5    4     500GB HDD
# 1039       HP         Workstation    15.6  Intel Core i7    8     256GB SSD
# 1040   Lenovo            Notebook    14.0  Intel Core i5    8     180GB SSD
# 1047       HP             Netbook    12.5  Intel Core i5    4     128GB SSD
# 1053     Dell           Ultrabook    12.5  Intel Core i3    4     500GB HDD
# 1054     Dell           Ultrabook    12.5  Intel Core i3    4     128GB SSD
# 1056       HP         Workstation    17.3  Intel Core i7    8       1TB HDD
# 1058     Dell           Ultrabook    12.5  Intel Core i5    8     256GB SSD
# 1064     Dell            Notebook    15.6  Intel Core i5    4     500GB HDD
# 1073       HP            Notebook    14.0  Intel Core i5    8     256GB SSD
# 1078       HP           Ultrabook    12.5  Intel Core i5    8     256GB SSD
# 1082   Lenovo  2 in 1 Convertible    14.0  Intel Core i7    8     512GB SSD
# 1087       HP         Workstation    17.3  Intel Core i7    8     256GB SSD
# 1090       HP           Ultrabook    15.6  Intel Core i7    8     256GB SSD
# 1094       HP         Workstation    15.6  Intel Core i7    8     256GB SSD
# 1096       HP         Workstation    15.6  Intel Core i7    8     256GB SSD
# 1097       HP           Ultrabook    12.5  Intel Core i7    8     256GB SSD
# 1099       HP            Notebook    15.6  Intel Core i5    8     256GB SSD
# 1108   Lenovo           Ultrabook    14.0  Intel Core i7   12     512GB SSD
# 1111   Lenovo           Ultrabook    14.0  Intel Core i7    8     256GB SSD
# 1127   Lenovo            Notebook    15.6  Intel Core i7    4  1.0TB Hybrid
# 1173     Dell           Ultrabook    12.5  Intel Core i5    8     256GB SSD
# 1185       HP           Ultrabook    14.0  Intel Core i7    8     256GB SSD
# 1186     Dell            Notebook    15.6  Intel Core i5    4     500GB HDD
# 1193       HP            Notebook    14.0  Intel Core i5    4     256GB SSD
# 1207   Lenovo            Notebook    15.6  Intel Core i7    8  1.0TB Hybrid
#
#                 Gpu      OpSys  Weight   Price  X_res  Y_res  IPS  \
# 506        Intel HD  Windows 7    2.02  124957   1920   1080    0
# 596        Intel HD  Windows 7    1.65  136614   1920   1080    0
# 598        Intel HD  Windows 7    1.88   86911   1366    768    0
# 677   Nvidia Quadro  Windows 7    2.18  172982   1920   1080    0
# 717   Nvidia Quadro  Windows 7    3.00  409282   1920   1080    1
# 725   Nvidia Quadro  Windows 7    2.59  145566   1920   1080    0
# 741   Nvidia Quadro  Windows 7    2.50  221007   3840   2160    0
# 804        Intel HD  Windows 7    1.54  174381   1920   1080    0
# 907        Intel HD  Windows 7    1.20  136148   1920   1080    0
# 931        Intel HD  Windows 7    1.70   93438   1366    768    0
# 936        Intel HD  Windows 7    1.20  111436   1920   1080    0
# 961        Intel HD  Windows 7    1.43  135122   1920   1080    0
# 971   Nvidia Quadro  Windows 7    2.40  276771   3840   2160    1
# 987        Intel HD  Windows 7    1.95  111436   1920   1080    0
# 992        Intel HD  Windows 7    2.09   99122   1920   1080    0
# 999        Intel HD  Windows 7    1.43  136987   1920   1080    0
# 1003       Intel HD  Windows 7    1.10  244320   2560   1440    1
# 1025       Intel HD  Windows 7    1.26  111809   1920   1080    0
# 1032       Intel HD  Windows 7    2.31   87657   1920   1080    0
# 1038       Intel HD  Windows 7    1.54   96142   1920   1080    0
# 1039        AMD GPU  Windows 7    1.90  139412   1920   1080    0
# 1040       Intel HD  Windows 7    1.70  111809   1920   1080    0
# 1047       Intel HD  Windows 7    2.40  149110   1366    768    0
# 1053       Intel HD  Windows 7    1.50  105855   1366    768    0
# 1054       Intel HD  Windows 7    1.50  108822   1366    768    0
# 1056        AMD GPU  Windows 7    3.00  270337   1920   1080    1
# 1058       Intel HD  Windows 7    1.50  131774   1366    768    0
# 1064        AMD GPU  Windows 7    2.24   71725   1366    768    0
# 1073       Intel HD  Windows 7    1.43  141090   1920   1080    0
# 1078       Intel HD  Windows 7    1.26  176712   1366    768    0
# 1082  Nvidia Quadro  Windows 7    1.80  191202   1920   1080    1
# 1087  Nvidia Quadro  Windows 7    3.00  368289   1920   1080    1
# 1090       Intel HD  Windows 7    1.88  202517   1920   1080    0
# 1094  Nvidia Quadro  Windows 7    2.59  207858   1920   1080    1
# 1096  Nvidia Quadro  Windows 7    2.00  177085   1920   1080    0
# 1097       Intel HD  Windows 7    1.26  214195   1920   1080    0
# 1099       Intel HD  Windows 7    1.88  147245   1920   1080    0
# 1108       Intel HD  Windows 7    1.40  214386   1920   1080    0
# 1111       Intel HD  Windows 7    1.70  139785   1920   1080    0
# 1127       Intel HD  Windows 7    2.32   76933   1920   1080    0
# 1173       Intel HD  Windows 7    1.26  159775   1920   1080    0
# 1185       Intel HD  Windows 7    1.54  204985   2560   1440    0
# 1186       Intel HD  Windows 7    2.24   68727   1366    768    0
# 1193       Intel HD  Windows 7    1.54  102576   1920   1080    0
# 1207        AMD GPU  Windows 7    2.32   83460   1920   1080    0
#
#       Touchscreen  Cpu_Speed
# 506             0        2.3
# 596             0        2.3
# 598             0        2.3
# 677             0        2.5
# 717             0        2.9
# 725             0        2.6
# 741             0        2.7
# 804             0        2.5
# 907             0        2.3
# 931             0        2.3
# 936             0        2.3
# 961             0        2.6
# 971             0        2.7
# 987             0        2.3
# 992             0        2.4
# 999             0        2.3
# 1003            0        2.6
# 1025            0        2.3
# 1032            0        2.3
# 1038            0        2.3
# 1039            0        2.5
# 1040            0        2.3
# 1047            0        2.3
# 1053            0        2.3
# 1054            0        2.3
# 1056            0        2.6
# 1058            0        2.3
# 1064            0        2.3
# 1073            0        2.3
# 1078            0        2.4
# 1082            1        2.6
# 1087            0        2.6
# 1090            0        2.5
# 1094            0        2.6
# 1096            0        2.6
# 1097            0        2.5
# 1099            0        2.3
# 1108            0        2.6
# 1111            0        2.6
# 1127            0        2.5
# 1173            1        2.4
# 1185            0        2.5
# 1186            0        2.3
# 1193            0        2.3
# 1207            0        2.5

# %%
df.sample()
# Out:
#      Company  TypeName  Inches            Cpu  Ram     Memory       Gpu  \
# 1188  Lenovo  Notebook    13.3  Intel Core i7   16  512GB SSD  Intel HD
#
#            OpSys  Weight   Price  X_res  Y_res  IPS  Touchscreen  Cpu_Speed
# 1188  Windows 10     1.4  139785   1920   1080    1            0        2.7

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 64GB SSD                           1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory'] = df['Memory'].astype('str').replace("\.0","",regex = True)
# Out:
# <ipython-input-309-06026c2f5366>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].astype('str').replace("\.0","",regex = True)

# %%
df['Memory'] = df['Memory'].str.replace("GB", "")
df['Memory'] = df['Memory'].str.replace("TB", "000")
# Out:
# <ipython-input-310-905247dd652b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].str.replace("GB", "")
# <ipython-input-310-905247dd652b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].str.replace("TB", "000")

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        215
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 64 Flash Storage                 10
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 1000 Hybrid                       7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 16 SSD                            3
# 512 SSD +  2000 HDD               3
# 1000 SSD +  1000 HDD              2
# 512 Flash Storage                 2
# 128 SSD +  2000 HDD               2
# 256 SSD +  500 HDD                2
# 256 SSD +  256 SSD                2
# 32 SSD                            2
# 128 HDD                           1
# 512 SSD +  1000 Hybrid            1
# 8 SSD                             1
# 240 SSD                           1
# 508 Hybrid                        1
# 512 SSD +  256 SSD                1
# 1000 HDD +  1000 HDD              1
# 64 Flash Storage +  1000 HDD      1
# 512 SSD +  512 SSD                1
# 64 SSD                            1
# 256 SSD +  1000 Hybrid            1
# Name: count, dtype: int64

# %%
new = df['Memory'].str.split("+", n =1, expand = True)
df['first'] = new[0]
df['first'] = df['first'].str.strip()
df['second'] = new[1]

df['Layer1HDD'] = df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash'] = df['first'].apply(lambda x:1 if "Flash" in x else 0)

df['first'] = df['first'].str.replace(r'\D', "", regex = True)

df['second'].fillna("0", inplace = True)
df['second'] = df['second'].str.strip()

df['Layer2HDD'] = df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash'] = df['second'].apply(lambda x:1 if "Flash" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '',regex = True)

df['first'] = df['first'].astype('int')
df['second'] = df['second'].astype('int')

df['HDD'] = df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD'] = df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid'] = df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash'] = df['first']*df['Layer1Flash']+df['second']*df['Layer2Flash']

df.drop(columns =['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash',
                  'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash'], inplace = True)
# Out:
# <ipython-input-312-0857745c9686>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first'] = new[0]
# <ipython-input-312-0857745c9686>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first'] = df['first'].str.strip()
# <ipython-input-312-0857745c9686>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'] = new[1]
# <ipython-input-312-0857745c9686>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1HDD'] = df['first'].apply(lambda x:1 if "HDD" in x else 0)
# <ipython-input-312-0857745c9686>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1SSD'] = df['first'].apply(lambda x:1 if "SSD" in x else 0)
# <ipython-input-312-0857745c9686>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1Hybrid'] = df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
# <ipython-input-312-0857745c9686>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1Flash'] = df['first'].apply(lambda x:1 if "Flash" in x else 0)
# <ipython-input-312-0857745c9686>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first'] = df['first'].str.replace(r'\D', "", regex = True)
# <ipython-input-312-0857745c9686>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['second'].fillna("0", inplace = True)
# <ipython-input-312-0857745c9686>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'].fillna("0", inplace = True)
# <ipython-input-312-0857745c9686>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'] = df['second'].str.strip()
# <ipython-input-312-0857745c9686>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2HDD'] = df['second'].apply(lambda x:1 if "HDD" in x else 0)
# <ipython-input-312-0857745c9686>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2SSD'] = df['second'].apply(lambda x:1 if "SSD" in x else 0)
# <ipython-input-312-0857745c9686>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2Hybrid'] = df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
# <ipython-input-312-0857745c9686>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2Flash'] = df['second'].apply(lambda x:1 if "Flash" in x else 0)
# <ipython-input-312-0857745c9686>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'] = df['second'].str.replace(r'\D', '',regex = True)
# <ipython-input-312-0857745c9686>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first'] = df['first'].astype('int')
# <ipython-input-312-0857745c9686>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'] = df['second'].astype('int')
# <ipython-input-312-0857745c9686>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HDD'] = df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
# <ipython-input-312-0857745c9686>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SSD'] = df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
# <ipython-input-312-0857745c9686>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hybrid'] = df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
# <ipython-input-312-0857745c9686>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Flash'] = df['first']*df['Layer1Flash']+df['second']*df['Layer2Flash']
# <ipython-input-312-0857745c9686>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns =['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash',

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches            Cpu  Ram               Memory  \
# 114     Dell  Notebook    15.6  Intel Core i7    8  256 SSD +  1000 HDD
# 1071    Asus    Gaming    17.3  Intel Core i7    8  128 SSD +  1000 HDD
# 636      MSI    Gaming    17.3  Intel Core i7    8  128 SSD +  1000 HDD
# 137     Acer  Notebook    17.3  Intel Core i3    4             1000 HDD
# 685   Lenovo  Notebook    14.0  Intel Core i5    8              256 SSD
#
#                  Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 114   Nvidia GeForce  Windows 10    2.16  105405   1920   1080    1
# 1071  Nvidia GeForce  Windows 10    3.52  122392   1920   1080    0
# 636   Nvidia GeForce  Windows 10    2.70  138644   1920   1080    0
# 137   Nvidia GeForce  Windows 10    3.00   61080   1920   1080    1
# 685   Nvidia GeForce  Windows 10    1.87   79923   1920   1080    1
#
#       Touchscreen  Cpu_Speed   HDD  SSD  Hybrid  Flash
# 114             0        1.8  1000  256       0      0
# 1071            0        2.6  1000  128       0      0
# 636             0        2.8  1000  128       0      0
# 137             0        2.7  1000    0       0      0
# 685             0        2.5     0  256       0      0

# %%
df.drop(columns= ['Memory'], inplace = True)
# Out:
# <ipython-input-314-d02779f057d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns= ['Memory'], inplace = True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches             Cpu  Ram             Gpu  \
# 1219  Lenovo  2 in 1 Convertible    14.0   Intel Core i7    4        Intel HD
# 366       HP            Notebook    15.6  AMD A - Series    4         AMD GPU
# 673   Lenovo            Notebook    15.6   Intel Core i5    4        Intel HD
# 134     Asus              Gaming    17.3   Intel Core i5    8  Nvidia GeForce
# 394     Acer            Notebook    15.6   Intel Core i7    8  Nvidia GeForce
#
#                     OpSys  Weight  Price  X_res  Y_res  IPS  Touchscreen  \
# 1219           Windows 10    1.80  59495   1920   1080    1            1
# 366            Windows 10    1.91  45599   1920   1080    0            0
# 673            Windows 10    2.10  57951   1920   1080    0            0
# 134            Windows 10    3.00  87470   1920   1080    0            0
# 394   Linux/Chrome/Others    2.50  81968   1920   1080    0            0
#
#       Cpu_Speed   HDD  SSD  Hybrid  Flash
# 1219        2.5     0  128       0      0
# 366         3.0     0  256       0      0
# 673         2.5  2000    0       0      0
# 134         2.5  1000  128       0      0
# 394         2.8     0  256       0      0

# %%
print(df.corr(numeric_only =  True)['Price'])
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# IPS            0.289225
# Touchscreen    0.161443
# Cpu_Speed      0.422535
# HDD           -0.093770
# SSD            0.654751
# Hybrid         0.025523
# Flash         -0.023384
# Name: Price, dtype: float64

# %%
df.drop(columns= ['Hybrid', 'Flash'], inplace = True)
# Out:
# <ipython-input-317-77c6fc1cb28f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns= ['Hybrid', 'Flash'], inplace = True)

# %%
df.sample(3)
# Out:
#     Company   TypeName  Inches            Cpu  Ram       Gpu       OpSys  \
# 982    Dell  Ultrabook    13.3  Intel Core i5    8  Intel HD  Windows 10
# 324  Lenovo   Notebook    15.6  Intel Core i3    4  Intel HD  Windows 10
# 258  Lenovo   Notebook    15.6  Intel Core i5    4  Intel HD       No OS
#
#      Weight   Price  X_res  Y_res  IPS  Touchscreen  Cpu_Speed   HDD  SSD
# 982    1.29  151441   3200   1800    0            1        2.5     0  256
# 324    1.85   41870   1920   1080    0            0        2.0  1000    0
# 258    2.20   43549   1920   1080    0            0        2.5  1000    0

# %%
df['HDD'].value_counts()
# Out:
# HDD
# 0       667
# 1000    398
# 500     126
# 2000     32
# 128       1
# Name: count, dtype: int64

# %%
sns.barplot(x = df['HDD'], y =df['Price'])
# Out:
# <Axes: xlabel='HDD', ylabel='Price'>

# %%
df['SSD'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='SSD'>

# %%
sns.barplot(x = df['SSD'], y = df['Price'])
# Out:
# <Axes: xlabel='SSD', ylabel='Price'>

# %%
# Pixel Density

# %%
df['PPI'] = round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('int')
# Out:
# <ipython-input-324-aad567f855d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PPI'] = round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('int')

# %%
df['PPI']
# Out:
# 0       227
# 1       128
# 2       141
# 3       221
# 4       227
#        ...
# 1219    157
# 1220    276
# 1221    112
# 1222    100
# 1223    100
# Name: PPI, Length: 1224, dtype: int64

# %%
print(df.corr(numeric_only = True)['Price'])
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# IPS            0.289225
# Touchscreen    0.161443
# Cpu_Speed      0.422535
# HDD           -0.093770
# SSD            0.654751
# PPI            0.483821
# Name: Price, dtype: float64

# %%
df.drop(columns = ['Inches', 'X_res', 'Y_res'], inplace = True)
# Out:
# <ipython-input-327-645c63b7df67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['Inches', 'X_res', 'Y_res'], inplace = True)

# %%
sns.histplot(df['PPI'], kde = True)
# Out:
# <Axes: xlabel='PPI', ylabel='Count'>

# %%
sns.scatterplot(x = df['PPI'], y = df['Price'])
# Out:
# <Axes: xlabel='PPI', ylabel='Price'>

# %%
df.head()
# Out:
#   Company   TypeName            Cpu  Ram         Gpu  OpSys  Weight   Price  \
# 0   Apple  Ultrabook  Intel Core i5    8  Intel Iris  MacOS    1.37  124929
# 1   Apple  Ultrabook  Intel Core i5    8    Intel HD  MacOS    1.34   83828
# 2      HP   Notebook  Intel Core i5    8    Intel HD  No OS    1.86   53620
# 3   Apple  Ultrabook  Intel Core i7   16     AMD GPU  MacOS    1.83  236622
# 4   Apple  Ultrabook  Intel Core i5    8  Intel Iris  MacOS    1.37  168189
#
#    IPS  Touchscreen  Cpu_Speed  HDD  SSD  PPI
# 0    1            0        2.3    0  128  227
# 1    0            0        1.8    0    0  128
# 2    0            0        2.5    0  256  141
# 3    1            0        2.7    0  512  221
# 4    1            0        3.1    0  256  227

# %%
df.to_csv("laptop_data_processed", index = False)

# %%
X =df.drop(columns = ['Price'])
y =df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.15, random_state = 36, stratify=df['Cpu'])

# %%
X_train.shape
# Out:
# (1040, 13)

# %%
X_train.shape,X_test.shape
# Out:
# ((1040, 13), (184, 13))

# %%
1040/1225
# Out:
# 0.8489795918367347

# %%
X_train.head()
# Out:
#      Company  TypeName            Cpu  Ram             Gpu       OpSys  \
# 1129     MSI    Gaming  Intel Core i7   16  Nvidia GeForce  Windows 10
# 215     Dell    Gaming  Intel Core i7   16  Nvidia GeForce  Windows 10
# 871       HP  Notebook  Intel Core i5    8        Intel HD  Windows 10
# 409     Dell  Notebook  Intel Core i5    8        Intel HD  Windows 10
# 293   Lenovo  Notebook  Intel Core i5    6  Nvidia GeForce  Windows 10
#
#       Weight  IPS  Touchscreen  Cpu_Speed   HDD  SSD  PPI
# 1129    1.91    0            0        2.6  1000  128  141
# 215     4.42    1            0        2.8  1000  256  127
# 871     1.49    0            0        2.5     0  256  166
# 409     2.14    0            0        2.5  1000    0  100
# 293     2.80    0            0        2.5  1000    0  106

# %%
y_train.head()
# Out:
# 1129    200806
# 215     229058
# 871      89522
# 409      50351
# 293      60520
# Name: Price, dtype: int64

# %%
X_test.head()
# Out:
#      Company  TypeName            Cpu  Ram             Gpu  \
# 1012     MSI    Gaming  Intel Core i7   16  Nvidia GeForce
# 230     Acer    Gaming  Intel Core i5    8  Nvidia GeForce
# 589     Dell  Notebook  Intel Core i5    4        Intel HD
# 80        HP  Notebook  Intel Core i5    8        Intel HD
# 132       HP  Notebook  Intel Core i7    8       Intel UHD
#
#                     OpSys  Weight  IPS  Touchscreen  Cpu_Speed   HDD  SSD  PPI
# 1012           Windows 10    2.94    0            0        2.6  1000  256  141
# 230            Windows 10    2.50    1            0        2.5     0  256  141
# 589   Linux/Chrome/Others    1.93    0            0        2.6   500    0  100
# 80             Windows 10    1.63    0            0        1.6     0  256  157
# 132            Windows 10    1.63    0            0        1.8     0  256  157

# %%
y_test.head()
# Out:
# 1012    169625
# 230      78891
# 589      81036
# 80       80197
# 132      92133
# Name: Price, dtype: int64

# %%
print(X.dtypes)
# Out:
# Company         object
# TypeName        object
# Cpu             object
# Ram              int64
# Gpu             object
# OpSys           object
# Weight         float64
# IPS              int64
# Touchscreen      int64
# Cpu_Speed      float64
# HDD              int64
# SSD              int64
# PPI              int64
# dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor

# %%
# Encoding
# (1) For output columns: use LabelEncoder()
# (2) For input columns:
    # (a) If Ordinal Data, use OrdinalEncoder()
    # (b) If Nominal Data, use OneHotEncoder()

# %%
# LinearRegression
# step1 = #OneHotEncoder using column Transformer
# step2 = #LR
# step1 + step2 #Pipeline

step1 = ColumnTransformer(transformers= [
    ('col_tnf', OneHotEncoder(drop = 'first'), [0,1,2,4,5])
],remainder = "passthrough")
step2 = LinearRegression()
pipe = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("RMSE: ", root_mean_squared_error(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8239034707814852
# RMSE:  29449.623146759073
# MAE:  21547.591094969735

# %%
X_test[X_test['Cpu']=="AMD F - Series"]
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Cpu, Ram, Gpu, OpSys, Weight, IPS, Touchscreen, Cpu_Speed, HDD, SSD, PPI]
# Index: []

# %%
X_train[X_train['Cpu']=="AMD F - Series"]
# Out:
#     Company TypeName             Cpu  Ram      Gpu       OpSys  Weight  IPS  \
# 88     Asus   Gaming  AMD F - Series    8  AMD GPU  Windows 10    2.45    0
# 900  Lenovo   Gaming  AMD F - Series   16  AMD GPU  Windows 10    2.50    1
#
#      Touchscreen  Cpu_Speed   HDD  SSD  PPI
# 88             0        3.0  1000    0  141
# 900            0        2.1  1000  512  141

# %%
# LassoRegression
step1 = ColumnTransformer(transformers= [
    ('col_tnf', OneHotEncoder(drop = 'first'), [0,1,2,4,5])
],remainder = "passthrough")
step2 = Lasso(alpha = 0.001)
pipe = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("RMSE: ", root_mean_squared_error(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8239034572344323
# RMSE:  29449.624279534368
# MAE:  21547.583356287345
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.060e+10, tolerance: 3.860e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
# RidgeRegression

step1 = ColumnTransformer(transformers= [
    ('col_tnf', OneHotEncoder(drop = 'first'), [0,1,2,4,5])
],remainder = "passthrough")
step2 = Ridge(alpha = 0.001)
pipe = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("RMSE: ", root_mean_squared_error(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8239005039258261
# RMSE:  29449.871227778807
# MAE:  21547.49768928314

# %%
# KNeighborsRegressor

step1 = ColumnTransformer(transformers= [
    ('col_tnf', OneHotEncoder(drop = 'first'), [0,1,2,4,5])
],remainder = "passthrough")
step2 = KNeighborsRegressor(n_neighbors = 9)
pipe = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("RMSE: ", root_mean_squared_error(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.6740219259231046
# RMSE:  40068.08056275754
# MAE:  27021.857487922705

# %%
# Support Vector Regressor

step1 = ColumnTransformer(transformers= [
    ('col_tnf', OneHotEncoder(drop = 'first'), [0,1,2,4,5])
],remainder = "passthrough")
step2 = SVR(C = 100000)
pipe = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("RMSE: ", root_mean_squared_error(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.5641234590375575
# RMSE:  46332.53808687529
# MAE:  31940.098993161482

# %%
# GradientBoostingRegressor
step1 = ColumnTransformer(transformers= [
('col_tnf', OneHotEncoder(drop = 'first'), [0,1,2,4,5])
],remainder = "passthrough")
step2 = GradientBoostingRegressor(n_estimators = 500, max_depth = 3)
pipe = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("RMSE: ", root_mean_squared_error(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8257207886257548
# RMSE:  29297.26885846421
# MAE:  17972.88519182515

# %%
import pickle

# %%
pickle.dump(df,open('df.pkl', 'wb'))
pickle.dump(pipe, open('pipe.pkl', 'wb'))

# %%
# !pip install streamlit --quiet

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np

df = pickle.load(open('df.pkl', 'rb'))
pipe = pickle.load(open('pipe.pkl', 'rb'))

st.title("laptop Price Predictor App")
st.text("This App is created using the data available on kaggle")
st.text("The prediction here is based on the data available, hence might not align with the real-life data")

company = st.selectbox('Manufacturing Company', df['Company'].unique(), index=4)
typename = st.selectbox('Type of laptop', df['TypeName'].unique(), index=1)
cpu = st.selectbox('Processor', df['Cpu'].unique(), index=0)
ram = st.radio('RAM(in GB)', [2,4,8,12,16,24,32,64,128], index =2, horizontal= True)
gpu = st.selectbox('Graphics Card',df['Gpu'].unique(), index = 1)
os = st.selectbox("Operating System",df['OpSys'].unique(), index = 2)
weight = st.slider('Weight(in kg)', min_value=0.7, max_value =4.7, value =2.0, step = 0.1)
ips = st.radio("IPS Display?", ["Yes", 'No'], horizontal = True)
touchscreen = st.radio("Touchscreen?", ['Yes', 'No'], horizontal= True)
cpu_speed = st.slider('CPU clock speed', min_value = 0.9, max_value = 3.6, value = 2.5, step = 0.1)
hdd = st.radio('Hard drive capacity(in GB)[If SSD, set HDD value to 0]',[0,128,500,1000,2000], horizontal= True)
ssd = st.radio("SSD capacity(in GB)", [0,8,16,32,64,128,256,512,1000,2000], horizontal= True, index = 7)
screen_size = st.slider("Screen size (measured in inches, calculated diagonally)", min_value = 10.0, max_value = 18.5, value = 15.6, step = 0.1)
screen_res = st.selectbox("Screen Resolution", ["1366x768", "1440x900", "1600x900", "1920x1080","1920x1200","2160x1440",
                                                "2256x1504","2304x1440","2400x1600","2560x1440","2560x1600","2736x1824","2880x1800","3200x1800","3840x2160"], index = 3)
if st.button("PREDICT PRICE"):
    ppi = None
    if (ips == 'Yes'):
        ips = 1
    else:
        ips = 0
    if ('touchscreen == "Yes'):
        touchscreen = 1
    else:
        touchscreen = 0
    X_res = int(screen_res.split('x')[0])
    Y_res = int(screen_res.split('x')[1])
    ppi = ((X_res**2)+(Y_res**2))**0.5/screen_size


    query = np.array([[company, typename, cpu, ram, gpu, os, weight, ips, touchscreen, cpu_speed, hdd, ssd, ppi]])
    op = pipe.predict(query)   # op is output
    f_op = int(round(op[0], -2)) #formated output f_op
    st.subheader("The estimated price of the laptop with the above selected configuration is ₹"+str(f_op))
# Out:
# Overwriting app.py
# Overwriting app.py

# %%
X.sample()
# Out:
#     Company  TypeName            Cpu  Ram       Gpu       OpSys  Weight  IPS  \
# 828    Acer  Notebook  Intel Core i5    8  Intel HD  Windows 10    1.56    1
#
#      Touchscreen  Cpu_Speed  HDD  SSD  PPI
# 828            0        2.5    0  256  157

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'MSI', 'Toshiba'],
#       dtype=object)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹⠸
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.233.160.52:8501
#
# ⠼⠴your url is: https://fancy-mails-cheat.loca.lt
#   Stopping...
# ^C

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
op = [97675.98955487578]
op
# Out:
# [97675.98955487578]

# %%
int(round(op[0], -2))
# Out:
# 97700

# %%
import sklearn
sklearn.__version__
# Out:
# '1.5.2'
